# %%
import yfinance as yf

tickerSymbol = '^IXIC'
tickerData = yf.Ticker(tickerSymbol)
tickerDf = tickerData.history(period='1d', start='2024-1-13', end='2024-3-12', interval = '15m')

# See the data
print(tickerDf)
tickerDf.to_csv('nasdaq.csv')
# Out:
#                                    Open          High           Low  \
# Datetime
# 2024-01-16 09:30:00-05:00  14905.665039  14938.710938  14881.009766
# 2024-01-16 09:45:00-05:00  14876.389648  14910.701172  14866.360352
# 2024-01-16 10:00:00-05:00  14902.736328  14934.326172  14892.898438
# 2024-01-16 10:15:00-05:00  14934.433594  14977.805664  14925.548828
# 2024-01-16 10:30:00-05:00  14974.114258  14992.057617  14954.064453
# ...                                 ...           ...           ...
# 2024-03-11 14:45:00-04:00  16057.845703  16076.823242  16053.979492
# 2024-03-11 15:00:00-04:00  16057.684570  16058.118164  16030.704102
# 2024-03-11 15:15:00-04:00  16030.795898  16034.460938  16012.697266
# 2024-03-11 15:30:00-04:00  16017.302734  16034.933594  16007.973633
# 2024-03-11 15:45:00-04:00  16032.431641  16040.884766  16003.586914
#
#                                   Close     Volume  Dividends  Stock Splits
# Datetime
# ...
